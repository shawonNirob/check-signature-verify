# %%
pip install numpy
# Out:
# Requirement already satisfied: numpy in ./llama-env/lib/python3.10/site-packages (1.26.4)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python matplotlib
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 5.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: matplotlib in ./llama-env/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: numpy>=1.21.2 in ./llama-env/lib/python3.10/site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./llama-env/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in ./llama-env/lib/python3.10/site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in ./llama-env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in ./llama-env/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./llama-env/lib/python3.10/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: contourpy>=1.0.1 in ./llama-env/lib/python3.10/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in ./llama-env/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in ./llama-env/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: six>=1.5 in ./llama-env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.140-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 1.8 MB/s eta 0:00:001.8 MB/s eta 0:00:01
# Requirement already satisfied: matplotlib>=3.3.0 in ./llama-env/lib/python3.10/site-packages (from ultralytics) (3.10.1)
# Requirement already satisfied: numpy>=1.23.0 in ./llama-env/lib/python3.10/site-packages (from ultralytics) (1.26.4)
# Collecting torchvision>=0.9.0
#   Downloading torchvision-0.22.0-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 7.0 MB/s eta 0:00:00 MB/s eta 0:00:01:01m
# Collecting scipy>=1.4.1
#   Downloading scipy-1.15.3-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 5.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: pandas>=1.1.4 in ./llama-env/lib/python3.10/site-packages (from ultralytics) (2.2.3)
# Collecting ultralytics-thop>=2.0.0
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Requirement already satisfied: pyyaml>=5.3.1 in ./llama-env/lib/python3.10/site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: pillow>=7.1.2 in ./llama-env/lib/python3.10/site-packages (from ultralytics) (11.2.1)
# Collecting py-cpuinfo
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: tqdm>=4.64.0 in ./llama-env/lib/python3.10/site-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: requests>=2.23.0 in ./llama-env/lib/python3.10/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: opencv-python>=4.6.0 in ./llama-env/lib/python3.10/site-packages (from ultralytics) (4.11.0.86)
# Requirement already satisfied: psutil in ./llama-env/lib/python3.10/site-packages (from ultralytics) (7.0.0)
# Requirement already satisfied: torch>=1.8.0 in ./llama-env/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: pyparsing>=2.3.1 in ./llama-env/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in ./llama-env/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in ./llama-env/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./llama-env/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.57.0)
# Requirement already satisfied: cycler>=0.10 in ./llama-env/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: packaging>=20.0 in ./llama-env/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in ./llama-env/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: tzdata>=2022.7 in ./llama-env/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in ./llama-env/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./llama-env/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2025.4.26)
# Requirement already satisfied: idna<4,>=2.5 in ./llama-env/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./llama-env/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./llama-env/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: filelock in ./llama-env/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./llama-env/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.13.2)
# Requirement already satisfied: networkx in ./llama-env/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: sympy in ./llama-env/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (1.14.0)
# Requirement already satisfied: jinja2 in ./llama-env/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in ./llama-env/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Collecting torch>=1.8.0
#   Downloading torch-2.7.0-cp310-none-macosx_11_0_arm64.whl (68.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.6/68.6 MB 4.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: six>=1.5 in ./llama-env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./llama-env/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./llama-env/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Installing collected packages: py-cpuinfo, scipy, torch, ultralytics-thop, torchvision, ultralytics
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.2
#     Uninstalling torch-2.2.2:
#       Successfully uninstalled torch-2.2.2
# Successfully installed py-cpuinfo-9.0.0 scipy-1.15.3 torch-2.7.0 torchvision-0.22.0 ultralytics-8.3.140 ultralytics-thop-2.0.14
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load the model
model = YOLO("yolov8s.pt")

# Load an image
image_path = "sonali_bank_check.jpg"
results = model(image_path)

# Visualize results
results[0].show()

# Or save the results
results[0].save(filename="output.jpg")
# Out:
# image 1/1 /Users/shawon/builder/llm/sonali_bank_check.jpg: 384x640 1 signature, 77.1ms
# Speed: 1.8ms preprocess, 77.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# 'output.jpg'

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt

# Load the YOLOv8 signature detector
model = YOLO("yolov8s.pt")

# Load image
image_path = "sonali_bank_check.jpg"
image = cv2.imread(image_path)

# Run inference
results = model(image)

# Extract detections
boxes = results[0].boxes  # Boxes object

for i, box in enumerate(boxes):
    # xyxy format (x1, y1, x2, y2)
    x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
    
    # Crop the signature
    cropped = image[y1:y2, x1:x2]
    
    # Save or display the crop
    crop_path = f"signature_crop_{i+1}.jpg"
    cv2.imwrite(crop_path, cropped)
    print(f"Cropped signature saved to: {crop_path}")

    # Optional: show the cropped signature
    plt.imshow(cv2.cvtColor(cropped, cv2.COLOR_BGR2RGB))
    plt.title(f"Signature {i+1}")
    plt.axis('off')
    plt.show()
# Out:
# 0: 384x640 1 signature, 74.0ms
# Speed: 1.8ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Cropped signature saved to: signature_crop_1.jpg

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load model and image
model = YOLO("yolov8s.pt")
image_path = "sonali_bank_check.jpg"
image = cv2.imread(image_path)
results = model(image)

# Process each detected signature
for i, box in enumerate(results[0].boxes):
    x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
    cropped = image[y1:y2, x1:x2]

    # Step 1: Convert to grayscale
    gray = cv2.cvtColor(cropped, cv2.COLOR_BGR2GRAY)

    # Step 2: Remove background noise using bilateral filter
    filtered = cv2.bilateralFilter(gray, 11, 75, 75)

    # Step 3: Apply adaptive threshold to separate ink from background
    thresh = cv2.adaptiveThreshold(filtered, 255, 
                                   cv2.ADAPTIVE_THRESH_GAUSSIAN_C, 
                                   cv2.THRESH_BINARY_INV, 15, 8)

    # Step 4: Morphological operations to remove noise
    kernel = np.ones((2, 2), np.uint8)
    denoised = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=1)

    # Save and show the result
    result_path = f"denoised_signature_{i+1}.png"
    cv2.imwrite(result_path, denoised)
    print(f"Saved denoised signature: {result_path}")

    plt.imshow(denoised, cmap='gray')
    plt.title(f"Denoised Signature {i+1}")
    plt.axis('off')
    plt.show()
# Out:
# 0: 384x640 1 signature, 89.5ms
# Speed: 2.1ms preprocess, 89.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Saved denoised signature: denoised_signature_1.png

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from ultralytics import YOLO

def isolate_signature(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Threshold to binary image (signature in white, background in black)
    _, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Create empty mask to draw filtered contours
    mask = np.zeros_like(binary)

    # Filter and draw only meaningful signature-like contours
    for cnt in contours:
        area = cv2.contourArea(cnt)
        x, y, w, h = cv2.boundingRect(cnt)

        # Filter conditions
        if area > 100 and w > 10 and h > 10:  # Skip tiny specks
            mask = cv2.drawContours(mask, [cnt], -1, 255, -1)  # Fill the contour

    # Final result (bitwise AND to extract the denoised signature)
    result = cv2.bitwise_and(binary, mask)

    return result

# Load model and image
model = YOLO("yolov8s.pt")
image_path = "sonali_bank_cheque_2.jpg"
image = cv2.imread(image_path)
results = model(image)

# Process each detected signature box
for i, box in enumerate(results[0].boxes):
    x1, y1, x2, y2 = map(int, box.xyxy[0].tolist())
    cropped = image[y1:y2, x1:x2]

    # Isolate signature
    cleaned = isolate_signature(cropped)

    # Save and display
    output_path = f"clean_signature_{i+1}.png"
    cv2.imwrite(output_path, cleaned)
    print(f"Saved clean signature: {output_path}")

    plt.imshow(cleaned, cmap='gray')
    plt.title(f"Clean Signature {i+1}")
    plt.axis('off')
    plt.show()
# Out:
# 0: 384x640 1 signature, 69.9ms
# Speed: 2.1ms preprocess, 69.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Saved clean signature: clean_signature_1.png
